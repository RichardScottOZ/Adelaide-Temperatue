# %%
import pandas as pd
import numpy as np
import xarray as xr
pd.set_option('display.max_columns', 500)

# %%
#West Terrance
dfWT = pd.read_csv(r'J:\Scott31082021MSLPAdelaide\HM01X_Data_023034_9999999910018540.txt', low_memory=False)

# %%
dfWT.dtypes
# Out:
# hm                                                         object
# Station Number                                              int64
# Year Month Day Hour Minutes in YYYY                         int64
# MM                                                          int64
# DD                                                          int64
# HH24                                                        int64
# MI format in Local time                                     int64
# Year Month Day Hour Minutes in YYYY.1                       int64
# MM.1                                                        int64
# DD.1                                                        int64
# HH24.1                                                      int64
# MI format in Local standard time                            int64
# Precipitation since 9am local time in mm                   object
# Quality of precipitation since 9am local time              object
# ...

# %%
dfWT['Station level pressure in hPa'].unique()
# Out:
# array(['1015.2', '1015.1', '1015.0', '1014.9', '1014.8', '1015.4',
#        '1015.6', '1016.0', '1016.1', '1016.6', '1017.0', '1017.2',
#        '1017.6', '1017.7', '1017.8', '1017.4', '1017.3', '1016.8',
#        '1016.7', '1016.3', '1016.2', '1016.4', '1016.9', '1017.9',
#        '1018.1', '1018.0', '1017.5', '1017.1', '1018.2', '1018.3',
#        '1016.5', '1015.7', '1014.7', '1014.2', '1014.0', '1013.5',
#        '1013.1', '1012.7', '1012.5', '1012.6', '1012.4', '1012.2',
#        '1012.0', '1011.7', '1011.6', '1011.3', '1011.0', '1011.1',
#        '1010.6', '1010.3', '1010.0', '1009.3', '1008.9', '1008.6',
#        '1008.3', '1008.1', '1007.8', '1008.0', '1008.2', '1008.5',
#        '1008.4', '1007.9', '1006.5', '1006.1', '1005.8', '1005.6',
#        '1005.1', '1004.9', '1004.3', '1003.7', '1003.3', '1002.6',
#        '1002.1', '1001.7', '1001.4', '1000.8', '1000.7', '1000.5',
#        '1000.1', '1000.0', '1001.8', '1002.0', '1004.6', '1004.8',
# ...

# %%
dfWT.shape
# Out:
# (31268, 34)

# %%
badvalue = '      '

dfWT = dfWT.loc[dfWT['Station level pressure in hPa'] != badvalue]
dfWT.shape
# Out:
# (31247, 34)

# %%
dfWT['Station level pressure in hPa'] = dfWT['Station level pressure in hPa'].astype('float32')
dfWT['Station level pressure in hPa'].plot()
# Out:
# <ipython-input-17-7a003f7fc4cd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfWT['Station level pressure in hPa'] = dfWT['Station level pressure in hPa'].astype('float32')
# <AxesSubplot:>

# %%
dfWT.head()
# Out:
#    hm  Station Number  Year Month Day Hour Minutes in YYYY  MM  DD  HH24  \
# 0  hm           23034                                 2020   1   1     1
# 1  hm           23034                                 2020   1   1     1
# 2  hm           23034                                 2020   1   1     2
# 3  hm           23034                                 2020   1   1     2
# 4  hm           23034                                 2020   1   1     3
#
#    MI format in Local time  Year Month Day Hour Minutes in YYYY.1  MM.1  DD.1  \
# 0                        0                                   2020     1     1
# 1                       30                                   2020     1     1
# 2                        0                                   2020     1     1
# 3                       30                                   2020     1     1
# 4                        0                                   2020     1     1
#
#    HH24.1  MI format in Local standard time  \
# ...

# %%
dfWT.describe()
# Out:
#        Station Number  Year Month Day Hour Minutes in YYYY            MM  \
# count         31247.0                         31247.000000  31247.000000
# mean          23034.0                          2020.399718      5.756297
# std               0.0                             0.489848      3.169401
# min           23034.0                          2020.000000      1.000000
# 25%           23034.0                          2020.000000      3.000000
# 50%           23034.0                          2020.000000      6.000000
# 75%           23034.0                          2021.000000      8.000000
# max           23034.0                          2021.000000     12.000000
#
#                  DD          HH24  MI format in Local time  \
# count  31247.000000  31247.000000             31247.000000
# mean      15.727206     11.484975                15.997696
# std        8.778685      6.912523                15.579277
# min        1.000000      0.000000                 0.000000
# ...

# %%
number = 1 # number of zeroes to add
dfWT['MMS'] = dfWT['MM'].astype('str')
dfWT['DDS'] = dfWT['DD'].astype('str')
dfWT['HHS'] = dfWT['HH24'].astype('str')
dfWT['MIS'] = dfWT['MI format in Local time'].astype('str')

dfWT['MMS'] = dfWT['MMS'].str.zfill(2)
dfWT['DDS'] = dfWT['DDS'].str.zfill(2)
dfWT['HHS'] = dfWT['HHS'].str.zfill(2)
dfWT['MIS'] = dfWT['MIS'].str.zfill(2)

dfWT['datesort'] = dfWT['Year Month Day Hour Minutes in YYYY'].astype('str') + dfWT['MMS'] + dfWT['DDS'] + dfWT['HHS'] + dfWT['MIS']
# Out:
# <ipython-input-28-7f62aa786fc1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfWT['MMS'] = dfWT['MM'].astype('str')
# <ipython-input-28-7f62aa786fc1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfWT['DDS'] = dfWT['DD'].astype('str')
# <ipython-input-28-7f62aa786fc1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dfWT['datesort']
# Out:
# 0        202001010100
# 1        202001010130
# 2        202001010200
# 3        202001010230
# 4        202001010300
#              ...
# 31263    202108310530
# 31264    202108310600
# 31265    202108310630
# 31266    202108310700
# 31267    202108310730
# Name: datesort, Length: 31247, dtype: object

# %%
dfWT['datesortint'] = dfWT['datesort'].astype('int64')
# Out:
# <ipython-input-32-601c623f814b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfWT['datesortint'] = dfWT['datesort'].astype('int64')

# %%
dfWT['datediff'] = dfWT['datesortint'].diff()
dfWT['pressurediff'] = dfWT['datesortint'].diff()
# Out:
# <ipython-input-33-2deaa4789235>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfWT['datediff'] = dfWT['datesortint'].diff()

# %%
dfWT['pressurediff'] = dfWT['Station level pressure in hPa'].diff()
# Out:
# <ipython-input-35-85b5eab7b9f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfWT['pressurediff'] = dfWT['Station level pressure in hPa'].diff()

# %%
dfWT['pressurediff'].plot()
# Out:
# <AxesSubplot:>

# %%
dfWT['pressurediffH'] = dfWT['Station level pressure in hPa'].diff(periods=2)
# Out:
# <ipython-input-37-ff29022d44a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfWT['pressurediffH'] = dfWT['Station level pressure in hPa'].diff(periods=2)

# %%
dfWT['pressurediffH'].plot()
# Out:
# <AxesSubplot:>

# %%
dfWT['pressurediff3H'] = dfWT['Station level pressure in hPa'].diff(periods=6)
# Out:
# <ipython-input-41-aa55863f6ac5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfWT['pressurediff3H'] = dfWT['Station level pressure in hPa'].diff(periods=6)

# %%
dfWT['pressurediff3H'].plot()
# Out:
# <AxesSubplot:>

# %%
dfWT['pressurediff6H'] = dfWT['Station level pressure in hPa'].diff(periods=12)
dfWT['pressurediff6H'].plot()
# Out:
# <ipython-input-43-4e2fad6d1a93>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfWT['pressurediff6H'] = dfWT['Station level pressure in hPa'].diff(periods=12)
# <AxesSubplot:>

# %%
dfWT['pressurediff12H'] = dfWT['Station level pressure in hPa'].diff(periods=24)
dfWT['pressurediff12H'].plot(title='12 Hourly Difference in West Adelaide Barometric Pressure',figsize=(24,10))
# Out:
# <ipython-input-56-d8058e370fd0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfWT['pressurediff12H'] = dfWT['Station level pressure in hPa'].diff(periods=24)
# <AxesSubplot:title={'center':'12 Hourly Difference in West Adelaide Barometric Pressure'}>
